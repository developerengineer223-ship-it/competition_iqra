# %%
import pandas as pd
from sklearn.model_selection import train_test_split 
from sklearn.metrics import accuracy_score
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline

# %%
# Load the dataset
df = pd.read_csv('sentiment_dataset.csv')
df
# Out:
#                                             review sentiment
# 0     The product quality is amazing and I love it  Positive
# 1          Very bad experience, will not buy again  Negative
# 2               Delivery was okay, nothing special   Neutral
# 3   Absolutely fantastic service and fast delivery  Positive
# 4                The item arrived damaged and late  Negative
# 5                             It works as expected   Neutral
# 6      I am extremely satisfied with this purchase  Positive
# 7       Worst product ever, totally waste of money  Negative
# 8                     Average quality, not too bad   Neutral
# 9                Highly recommend this to everyone  Positive
# 10                   Customer support is very poor  Negative
# 11                            The design is decent   Neutral
# 12    Excellent performance and great battery life  Positive
# 13                             Not worth the price  Negative
# 14                        It is fine for daily use   Neutral
# 15             Superb experience, will order again  Positive
# 16       The product stopped working after one day  Negative
# 17                  Nothing extraordinary but okay   Neutral
# 18                      Very खुश with the purchase  Positive
# 19              Terrible packaging and broken item  Negative
# 20                           The product is usable   Neutral
# 21                 I love the features and quality  Positive
# 22                         Completely disappointed  Negative
# 23                                 It does the job   Neutral
# 24             Best purchase I have made this year  Positive
# 25                  The color faded after one wash  Negative
# 26                         Just okay for the price   Neutral
# 27             Brilliant product and fast shipping  Positive
# 28                             Received wrong item  Negative
# 29                        Not bad, could be better   Neutral
# 30                Very impressive and high quality  Positive
# 31            Horrible experience with this seller  Negative
# 32                                It is acceptable   Neutral
# 33                           Great value for money  Positive
# 34                      Battery drains too quickly  Negative
# 35                             Average performance   Neutral
# 36               I am very happy with this product  Positive
# 37                        The material feels cheap  Negative
# 38                        Nothing special about it   Neutral
# 39                        Exceeded my expectations  Positive
# 40                  Late delivery and poor service  Negative
# 41                                   It works fine   Neutral
# 42                    Fantastic quality and design  Positive
# 43                            Not satisfied at all  Negative
# 44                      Okay product for daily use   Neutral
# 45                      Loved it, highly recommend  Positive
# 46                      Very disappointing quality  Negative
# 47                            Decent but not great   Neutral
# 48                   Five stars, excellent product  Positive
# 49                       Will never buy this again  Negative

# %%
# Feature selection
X = df.drop(columns="sentiment")
X
# Out:
#                                             review
# 0     The product quality is amazing and I love it
# 1          Very bad experience, will not buy again
# 2               Delivery was okay, nothing special
# 3   Absolutely fantastic service and fast delivery
# 4                The item arrived damaged and late
# 5                             It works as expected
# 6      I am extremely satisfied with this purchase
# 7       Worst product ever, totally waste of money
# 8                     Average quality, not too bad
# 9                Highly recommend this to everyone
# 10                   Customer support is very poor
# 11                            The design is decent
# 12    Excellent performance and great battery life
# 13                             Not worth the price
# 14                        It is fine for daily use
# 15             Superb experience, will order again
# 16       The product stopped working after one day
# 17                  Nothing extraordinary but okay
# 18                      Very खुश with the purchase
# 19              Terrible packaging and broken item
# 20                           The product is usable
# 21                 I love the features and quality
# 22                         Completely disappointed
# 23                                 It does the job
# 24             Best purchase I have made this year
# 25                  The color faded after one wash
# 26                         Just okay for the price
# 27             Brilliant product and fast shipping
# 28                             Received wrong item
# 29                        Not bad, could be better
# 30                Very impressive and high quality
# 31            Horrible experience with this seller
# 32                                It is acceptable
# 33                           Great value for money
# 34                      Battery drains too quickly
# 35                             Average performance
# 36               I am very happy with this product
# 37                        The material feels cheap
# 38                        Nothing special about it
# 39                        Exceeded my expectations
# 40                  Late delivery and poor service
# 41                                   It works fine
# 42                    Fantastic quality and design
# 43                            Not satisfied at all
# 44                      Okay product for daily use
# 45                      Loved it, highly recommend
# 46                      Very disappointing quality
# 47                            Decent but not great
# 48                   Five stars, excellent product
# 49                       Will never buy this again

# %%
y = df["sentiment"]
y
# Out:
# 0     Positive
# 1     Negative
# 2      Neutral
# 3     Positive
# 4     Negative
# 5      Neutral
# 6     Positive
# 7     Negative
# 8      Neutral
# 9     Positive
# 10    Negative
# 11     Neutral
# 12    Positive
# 13    Negative
# 14     Neutral
# 15    Positive
# 16    Negative
# 17     Neutral
# 18    Positive
# 19    Negative
# 20     Neutral
# 21    Positive
# 22    Negative
# 23     Neutral
# 24    Positive
# 25    Negative
# 26     Neutral
# 27    Positive
# 28    Negative
# 29     Neutral
# 30    Positive
# 31    Negative
# 32     Neutral
# 33    Positive
# 34    Negative
# 35     Neutral
# 36    Positive
# 37    Negative
# 38     Neutral
# 39    Positive
# 40    Negative
# 41     Neutral
# 42    Positive
# 43    Negative
# 44     Neutral
# 45    Positive
# 46    Negative
# 47     Neutral
# 48    Positive
# 49    Negative
# Name: sentiment, dtype: str

# %%
# 2. splitting of data set into training and testing (randomly)
X_train, X_test, y_train, y_test =  train_test_split(X,y,test_size=0.20)
X_train
# Out:
#                                             review
# 18                      Very खुश with the purchase
# 12    Excellent performance and great battery life
# 10                   Customer support is very poor
# 31            Horrible experience with this seller
# 48                   Five stars, excellent product
# 23                                 It does the job
# 26                         Just okay for the price
# 45                      Loved it, highly recommend
# 32                                It is acceptable
# 3   Absolutely fantastic service and fast delivery
# 13                             Not worth the price
# 14                        It is fine for daily use
# 43                            Not satisfied at all
# 35                             Average performance
# 17                  Nothing extraordinary but okay
# 7       Worst product ever, totally waste of money
# 40                  Late delivery and poor service
# 39                        Exceeded my expectations
# 20                           The product is usable
# 2               Delivery was okay, nothing special
# 46                      Very disappointing quality
# 41                                   It works fine
# 22                         Completely disappointed
# 49                       Will never buy this again
# 11                            The design is decent
# 42                    Fantastic quality and design
# 21                 I love the features and quality
# 38                        Nothing special about it
# 6      I am extremely satisfied with this purchase
# 27             Brilliant product and fast shipping
# 28                             Received wrong item
# 0     The product quality is amazing and I love it
# 29                        Not bad, could be better
# 8                     Average quality, not too bad
# 16       The product stopped working after one day
# 36               I am very happy with this product
# 30                Very impressive and high quality
# 5                             It works as expected
# 25                  The color faded after one wash
# 47                            Decent but not great

# %%
vectorizer = TfidfVectorizer()

X = vectorizer.fit_transform(X)

y = vectorizer.transform(y)

# %%
model = SVM(kernel="linear")

model.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 model = SVM(kernel="linear")
#       2
#       3 model.fit(X_train,y_train)
#
# NameError: name 'SVM' is not defined

# %%
# Train the model
model.fit(X_train, y_train)
